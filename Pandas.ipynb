# %% [markdown]
# # Introduction to Pandas

# %%
import pandas as pd

# %%
series1 = pd.Series([1, 2, 3, 4])

# %%
series1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
#Changing index name
series2 = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
series2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# # Series Object in Pandas

# %%
list1 = [1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list1
df = pd.DataFrame(list1)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# # How to create a DataFrame

# %%
list_of_lists = [['apple',10],['mango',12],['banana',13]]
df = pd.DataFrame(list_of_lists,columns=['fruit','count'],dtype=int)
df
# Out:
#     fruit  count
# 0   apple     10
# 1   mango     12
# 2  banana     13

# %%
dict1 = {'fruits':['apple','mango','banana'], 'count':[20,12,13]}
df = pd.DataFrame(dict1)

# %%
df
# Out:
#    fruits  count
# 0   apple     20
# 1   mango     12
# 2  banana     13

# %%
series = pd.Series([6,10], index = ['a','b'])
df = pd.DataFrame(series)
df
# Out:
#     0
# a   6
# b  10

# %%
import numpy as np

# %%
arr = np.array([[10,20],['James','Jones']])
df = pd.DataFrame({'name':arr[1], 'salary':arr[0]})
df
# Out:
#     name salary
# 0  James     10
# 1  Jones     20

# %% [markdown]
# # How to perform merge Operation

# %%
player = ['Player1','Player2','Player3']
points = [10,20,30]
title = ['game1','game2','game3']
df1 = pd.DataFrame({'Player' : player, 'Points' : points, 'Title': title})
df1
# Out:
#     Player  Points  Title
# 0  Player1      10  game1
# 1  Player2      20  game2
# 2  Player3      30  game3

# %%
player = ['Player1','Player5','Player6']
power = ['Punch','Kick','Elbow']
title = ['game1','game5','game6']
df2 = pd.DataFrame({'Player' : player, 'Power' : power, 'Title': title})
df2
# Out:
#     Player  Power  Title
# 0  Player1  Punch  game1
# 1  Player5   Kick  game5
# 2  Player6  Elbow  game6

# %%
# Inner Merge

# %%
df1.merge(df2, on = 'Title', how = 'inner')
# Out:
#   Player_x  Points  Title Player_y  Power
# 0  Player1      10  game1  Player1  Punch

# %%
df1.merge(df2, on = 'Player', how = 'inner')
# Out:
#     Player  Points Title_x  Power Title_y
# 0  Player1      10   game1  Punch   game1

# %%
df1.merge(df2)
# Out:
#     Player  Points  Title  Power
# 0  Player1      10  game1  Punch

# %%
#left merge

# %%
df1.merge(df2, on = 'Player', how = 'left')
# Out:
#     Player  Points Title_x  Power Title_y
# 0  Player1      10   game1  Punch   game1
# 1  Player2      20   game2    NaN     NaN
# 2  Player3      30   game3    NaN     NaN

# %%
df1.merge(df2, on = 'Player', how = 'right')
# Out:
#     Player  Points Title_x  Power Title_y
# 0  Player1    10.0   game1  Punch   game1
# 1  Player5     NaN     NaN   Kick   game5
# 2  Player6     NaN     NaN  Elbow   game6

# %%
# How to perform Join opertion in Pandas

# %%
player = ['Player1','Player5','Player6']
power = ['Punch','Kick','Elbow']
title = ['game1','game5','game6']
df3 = pd.DataFrame({'Player' : player, 'Power' : power, 'Title': title}, index = ['L1','L2','L3'])
df3
# Out:
#      Player  Power  Title
# L1  Player1  Punch  game1
# L2  Player5   Kick  game5
# L3  Player6  Elbow  game6

# %%
player = ['Player1','Player5','Player6']
power = ['Punch','Kick','Elbow']
title = ['game1','game5','game6']
df4 = pd.DataFrame({'Players' : player, 'Powers' : power, 'Titles': title}, index = ['L2','L3','L4'])
df4
# Out:
#     Players Powers Titles
# L2  Player1  Punch  game1
# L3  Player5   Kick  game5
# L4  Player6  Elbow  game6

# %%
#inner join

# %%
df3.join(df4, how = 'inner')
# Out:
#      Player  Power  Title  Players Powers Titles
# L2  Player5   Kick  game5  Player1  Punch  game1
# L3  Player6  Elbow  game6  Player5   Kick  game5

# %%
df3.join(df4, how = 'left')
# Out:
#      Player  Power  Title  Players Powers Titles
# L1  Player1  Punch  game1      NaN    NaN    NaN
# L2  Player5   Kick  game5  Player1  Punch  game1
# L3  Player6  Elbow  game6  Player5   Kick  game5

# %%
df3.join(df4, how = 'right')
# Out:
#      Player  Power  Title  Players Powers Titles
# L2  Player5   Kick  game5  Player1  Punch  game1
# L3  Player6  Elbow  game6  Player5   Kick  game5
# L4      NaN    NaN    NaN  Player6  Elbow  game6

# %%
df3.join(df4, how = 'outer')
# Out:
#      Player  Power  Title  Players Powers Titles
# L1  Player1  Punch  game1      NaN    NaN    NaN
# L2  Player5   Kick  game5  Player1  Punch  game1
# L3  Player6  Elbow  game6  Player5   Kick  game5
# L4      NaN    NaN    NaN  Player6  Elbow  game6

# %%
# Concationation of two dataframes in pandas

# %%
pd.concat([df3, df4])
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      Player  Players  Power Powers  Title Titles
# L1  Player1      NaN  Punch    NaN  game1    NaN
# L2  Player5      NaN   Kick    NaN  game5    NaN
# L3  Player6      NaN  Elbow    NaN  game6    NaN
# L2      NaN  Player1    NaN  Punch    NaN  game1
# L3      NaN  Player5    NaN   Kick    NaN  game5
# L4      NaN  Player6    NaN  Elbow    NaN  game6

# %% [markdown]
# # Importing csv files using pandas

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is AEE3-1B6E
#
#  Directory of C:\Users\91961\Python-3.7-Bootcamp
#
# 20-03-2020  14:06    <DIR>          .
# 20-03-2020  14:06    <DIR>          ..
# 20-03-2020  11:41    <DIR>          .ipynb_checkpoints
# 19-03-2020  17:14            88,984 data.csv
# 19-03-2020  17:15            28,352 data.npy
# 19-03-2020  17:19           116,385 data2.npz
# 14-03-2020  21:59             2,020 Dice Stimulator in Python.ipynb
# 14-03-2020  15:14            39,457 Introduction to Python 1.ipynb
# 14-03-2020  18:25            29,632 Introduction to Python 2.ipynb
# 13-03-2020  22:55            35,121 Introduction to python.ipynb
# 20-03-2020  11:35           409,641 Matplotlib.ipynb
# 19-03-2020  19:49           350,224 matplotlib.pdf
# 20-03-2020  11:38             1,700 mtcars .csv
# 15-03-2020  00:28           183,392 Numpy 1.pdf
# 19-03-2020  17:49            29,197 NumPy 2.ipynb
# 15-03-2020  00:28           235,896 Numpy 2.pdf
# ...

# %%
cars = pd.read_csv('mtcars.csv')

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
pwd # finding current directory
# Out:
# 'C:\\Users\\91961\\Python-3.7-Bootcamp'

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.head() # first five data
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
cars.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
cars.tail(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 22       AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# 23        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# 24  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# 25         Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 28    Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# 29      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 30     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# 31        Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 22     2
# 23     4
# 24     2
# 25     1
# 26     2
# 27     2
# 28     4
# 29     6
# 30     8
# ...

# %%
cars.shape
# Out:
# (32, 12)

# %%
cars.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
cars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
cars.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars.std() # standard deviation
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
cars.max()
# Out:
# model    Volvo 142E
# mpg            33.9
# cyl               8
# disp            472
# hp              335
# drat           4.93
# wt            5.424
# qsec           22.9
# vs                1
# am                1
# gear              5
# carb              8
# dtype: object

# %%
cars.min()
# Out:
# model    AMC Javelin
# mpg             10.4
# cyl                4
# disp            71.1
# hp                52
# drat            2.76
# wt             1.513
# qsec            14.5
# vs                 0
# am                 0
# gear               3
# carb               1
# dtype: object

# %%
cars.count() # non null value
# Out:
# model    32
# mpg      32
# cyl      32
# disp     32
# hp       32
# drat     32
# wt       32
# qsec     32
# vs       32
# am       32
# gear     32
# carb     32
# dtype: int64

# %%
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# # Data cleaning

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars.rename(columns={'model':'car'})
# Out:
#                     car   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars.qsec = cars.qsec.fillna(cars.qsec.mean())

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
cars[1:10]
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
cars = cars.drop(columns=['am'])

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     4
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     3
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     3
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     3
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     3
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1     4
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1     4
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1     4
# ...

# %%
cars.size
# Out:
# 352

# %%
cars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df = cars[['model','mpg','cyl','hp','drat','wt','qsec','vs','gear','carb']].corr()
df
# Out:
#            mpg       cyl        hp      drat        wt      qsec        vs  \
# mpg   1.000000 -0.852162 -0.776168  0.681172 -0.867659  0.418684  0.664039
# cyl  -0.852162  1.000000  0.832447 -0.699938  0.782496 -0.591242 -0.810812
# hp   -0.776168  0.832447  1.000000 -0.448759  0.658748 -0.708223 -0.723097
# drat  0.681172 -0.699938 -0.448759  1.000000 -0.712441  0.091205  0.440278
# wt   -0.867659  0.782496  0.658748 -0.712441  1.000000 -0.174716 -0.554916
# qsec  0.418684 -0.591242 -0.708223  0.091205 -0.174716  1.000000  0.744535
# vs    0.664039 -0.810812 -0.723097  0.440278 -0.554916  0.744535  1.000000
# gear  0.480285 -0.492687 -0.125704  0.699610 -0.583287 -0.212682  0.206023
# carb -0.550925  0.526988  0.749812 -0.090790  0.427606 -0.656249 -0.569607
#
#           gear      carb
# mpg   0.480285 -0.550925
# cyl  -0.492687  0.526988
# hp   -0.125704  0.749812
# drat  0.699610 -0.090790
# wt   -0.583287  0.427606
# qsec -0.212682 -0.656249
# vs    0.206023 -0.569607
# ...

# %%
#change mpg from string to float

# %%
cars.mpg = cars.mpg.astype(float)

# %%
cars.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 11 columns):
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 2.8+ KB

# %%
df = cars[['model','mpg','cyl','hp','drat','wt','qsec','vs','gear','carb']].corr()
df
# Out:
#            mpg       cyl        hp      drat        wt      qsec        vs  \
# mpg   1.000000 -0.852162 -0.776168  0.681172 -0.867659  0.418684  0.664039
# cyl  -0.852162  1.000000  0.832447 -0.699938  0.782496 -0.591242 -0.810812
# hp   -0.776168  0.832447  1.000000 -0.448759  0.658748 -0.708223 -0.723097
# drat  0.681172 -0.699938 -0.448759  1.000000 -0.712441  0.091205  0.440278
# wt   -0.867659  0.782496  0.658748 -0.712441  1.000000 -0.174716 -0.554916
# qsec  0.418684 -0.591242 -0.708223  0.091205 -0.174716  1.000000  0.744535
# vs    0.664039 -0.810812 -0.723097  0.440278 -0.554916  0.744535  1.000000
# gear  0.480285 -0.492687 -0.125704  0.699610 -0.583287 -0.212682  0.206023
# carb -0.550925  0.526988  0.749812 -0.090790  0.427606 -0.656249 -0.569607
#
#           gear      carb
# mpg   0.480285 -0.550925
# cyl  -0.492687  0.526988
# hp   -0.125704  0.749812
# drat  0.699610 -0.090790
# wt   -0.583287  0.427606
# qsec -0.212682 -0.656249
# vs    0.206023 -0.569607
# ...

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     4
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     3
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     3
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     3
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     3
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1     4
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1     4
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1     4
# ...

# %%
#Manipulation of dataframe
cars.iloc[:,0:4]
# Out:
#                   model   mpg  cyl   disp
# 0             Mazda RX4  21.0    6  160.0
# 1         Mazda RX4 Wag  21.0    6  160.0
# 2            Datsun 710  22.8    4  108.0
# 3        Hornet 4 Drive  21.4    6  258.0
# 4     Hornet Sportabout  18.7    8  360.0
# 5               Valiant  18.1    6  225.0
# 6            Duster 360  14.3    8  360.0
# 7             Merc 240D  24.4    4  146.7
# 8              Merc 230  22.8    4  140.8
# 9              Merc 280  19.2    6  167.6
# 10            Merc 280C  17.8    6  167.6
# 11           Merc 450SE  16.4    8  275.8
# 12           Merc 450SL  17.3    8  275.8
# 13          Merc 450SLC  15.2    8  275.8
# 14   Cadillac Fleetwood  10.4    8  472.0
# 15  Lincoln Continental  10.4    8  460.0
# 16    Chrysler Imperial  14.7    8  440.0
# 17             Fiat 128  32.4    4   78.7
# 18          Honda Civic  30.4    4   75.7
# 19       Toyota Corolla  33.9    4   71.1
# 20        Toyota Corona  21.5    4  120.1
# ...

# %%
cars.iloc[:,:]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     4
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     3
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     3
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     3
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     3
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1     4
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1     4
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1     4
# ...

# %%
cars.iloc[6:,4:]
# Out:
#      hp  drat     wt   qsec  vs  gear  carb
# 6   245  3.21  3.570  15.84   0     3     4
# 7    62  3.69  3.190  20.00   1     4     2
# 8    95  3.92  3.150  22.90   1     4     2
# 9   123  3.92  3.440  18.30   1     4     4
# 10  123  3.92  3.440  18.90   1     4     4
# 11  180  3.07  4.070  17.40   0     3     3
# 12  180  3.07  3.730  17.60   0     3     3
# 13  180  3.07  3.780  18.00   0     3     3
# 14  205  2.93  5.250  17.98   0     3     4
# 15  215  3.00  5.424  17.82   0     3     4
# 16  230  3.23  5.345  17.42   0     3     4
# 17   66  4.08  2.200  19.47   1     4     1
# 18   52  4.93  1.615  18.52   1     4     2
# 19   65  4.22  1.835  19.90   1     4     1
# 20   97  3.70  2.465  20.01   1     3     1
# 21  150  2.76  3.520  16.87   0     3     2
# 22  150  3.15  3.435  17.30   0     3     2
# 23  245  3.73  3.840  15.41   0     3     4
# 24  175  3.08  3.845  17.05   0     3     2
# 25   66  4.08  1.935  18.90   1     4     1
# ...

# %%
cars.loc[:,"model"]
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %%
cars.loc[:6,"model"]
# Out:
# 0            Mazda RX4
# 1        Mazda RX4 Wag
# 2           Datsun 710
# 3       Hornet 4 Drive
# 4    Hornet Sportabout
# 5              Valiant
# 6           Duster 360
# Name: model, dtype: object

# %%
cars.loc[:6,"model":"hp"]
# Out:
#                model   mpg  cyl   disp   hp
# 0          Mazda RX4  21.0    6  160.0  110
# 1      Mazda RX4 Wag  21.0    6  160.0  110
# 2         Datsun 710  22.8    4  108.0   93
# 3     Hornet 4 Drive  21.4    6  258.0  110
# 4  Hornet Sportabout  18.7    8  360.0  175
# 5            Valiant  18.1    6  225.0  105
# 6         Duster 360  14.3    8  360.0  245

# %%
cars['am'] = 1
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     4
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     3
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     3
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     3
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     3
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1     4
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1     4
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1     4
# ...

# %%
f = lambda x : x**2
cars['gear'] = cars['gear'].apply(f)
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0    16
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0    16
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1    16
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1     9
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     9
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     9
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     9
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1    16
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1    16
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1    16
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1    16
# ...

# %%
cars.sort_values(by = 'gear')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0     9
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0     9
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0     9
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0     9
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0     9
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1     9
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0     9
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0     9
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0     9
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     9
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1     9
# ...

# %%
cars.sort_values(by = 'gear', ascending=False)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0    25
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0    25
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0    25
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1    25
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0    25
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0    16
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0    16
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1    16
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1    16
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1    16
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1    16
# ...

# %%
cars['cyl'] > 6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
filter1 = cars['cyl'] > 6
filter_new = cars[filter1]
filter_new
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  gear  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     9
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     9
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0     9
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0     9
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0     9
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0     9
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0     9
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0     9
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0     9
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0     9
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0     9
# ...

# %%
filter2 = (cars['cyl'] > 6) & (cars['hp'] > 300)
filter_new = cars[filter2]
filter_new
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  gear  carb  am
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0    25     8   1
